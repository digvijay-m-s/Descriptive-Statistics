# %%
##Problem Statement
## to check whether there is any relationship customer characteristics and the product
## EDA

# %%
### load the necessary packages

import numpy as np
import pandas as pd

# %%
## load the Cardio data set
 

fit= pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/Statistics/main/CardioGoodFitness-1.csv")

# %%
## top 5 rows

fit.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
fit.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
fit.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %%
fit.tail(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 170   TM798   31    Male         16     Partnered      6        5   89641
# 171   TM798   33  Female         18     Partnered      4        5   95866
# 172   TM798   34    Male         16        Single      5        5   92131
# 173   TM798   35    Male         16     Partnered      4        5   92131
# 174   TM798   38    Male         18     Partnered      5        5  104581
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 170    260
# 171    200
# 172    150
# 173    360
# 174    150
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
fit.sample()
# Out:
#    Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 87   TM498   23   Male         14     Partnered      3        3   36384     95

# %%
fit.sample(5)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 179   TM798   48    Male         18     Partnered      4        5   95508
# 51    TM195   29  Female         14     Partnered      2        2   46617
# 145   TM798   23    Male         16        Single      4        5   48556
# 70    TM195   38    Male         14        Single      2        3   52302
# 42    TM195   27    Male         16        Single      4        3   54576
#
#      Miles
# 179    180
# 51      38
# 145    100
# 70      56
# 42      85

# %%
fit.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
fit.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
fit.info()

## gives info about the all the coulmns, if any missing values and data types of the column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
fit.columns

### name of all the columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
fit.shape #(rows, columns)
# Out:
# (180, 9)

# %%
## gives number of rows
fit.shape[0]
# Out:
# 180

# %%
## gives number of colums
fit.shape[1]
# Out:
# 9

# %%
## number of rows

len(fit)
# Out:
# 180

# %%
fit.isnull().sum()

## shows us total number of missing values
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
fit.isnull()

##tells us if there is any missing values as true or false
# Out:
#      Product    Age  Gender  Education  MaritalStatus  Usage  Fitness  Income  \
# 0      False  False   False      False          False  False    False   False
# 1      False  False   False      False          False  False    False   False
# 2      False  False   False      False          False  False    False   False
# 3      False  False   False      False          False  False    False   False
# 4      False  False   False      False          False  False    False   False
# ..       ...    ...     ...        ...            ...    ...      ...     ...
# 175    False  False   False      False          False  False    False   False
# 176    False  False   False      False          False  False    False   False
# 177    False  False   False      False          False  False    False   False
# 178    False  False   False      False          False  False    False   False
# 179    False  False   False      False          False  False    False   False
#
#      Miles
# 0    False
# ...

# %%
fit.dtypes

## tells us the data types of all the features
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fit.hist()

### histogram
### but here the plot are closely packed and overlapping
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Education'}>],
#        [<AxesSubplot:title={'center':'Usage'}>,
#         <AxesSubplot:title={'center':'Fitness'}>],
#        [<AxesSubplot:title={'center':'Income'}>,
#         <AxesSubplot:title={'center':'Miles'}>]], dtype=object)

# %%
fit.hist(figsize=(10,10))

### here we have mentioned the size of the figures using figsize=(10,10)
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Education'}>],
#        [<AxesSubplot:title={'center':'Usage'}>,
#         <AxesSubplot:title={'center':'Fitness'}>],
#        [<AxesSubplot:title={'center':'Income'}>,
#         <AxesSubplot:title={'center':'Miles'}>]], dtype=object)

# %%
import seaborn as sns

# %%
fit.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
sns.boxplot(x='Gender', y= 'Age', data=fit)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %%
fit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
pd.crosstab(fit["Education"],fit["Fitness"])
# Out:
# Fitness    1   2   3  4   5
# Education
# 12         0   1   2  0   0
# 13         0   2   2  1   0
# 14         0  11  35  8   1
# 15         0   1   3  1   0
# 16         1  11  50  8  15
# 18         1   0   4  5  13
# 20         0   0   0  0   1
# 21         0   0   1  1   1

# %%
pd.crosstab(fit["Education"],fit["Gender"])
# Out:
# Gender     Female  Male
# Education
# 12              0     3
# 13              1     4
# 14             30    25
# 15              2     3
# 16             35    50
# 18              7    16
# 20              0     1
# 21              1     2

# %%
pd.crosstab(fit["Age"],fit["Gender"])
# Out:
# Gender  Female  Male
# Age
# 18           0     1
# 19           1     3
# 20           2     3
# 21           3     4
# 22           3     4
# 23           7    11
# 24           6     6
# 25          10    15
# 26           6     6
# 27           2     5
# 28           5     4
# 29           3     3
# 30           3     4
# 31           3     3
# 32           1     3
# 33           6     2
# 34           2     4
# 35           4     4
# 36           0     1
# 37           2     0
# 38           2     5
# 39           0     1
# 40           2     3
# 41           0     1
# 42           0     1
# 43           0     1
# 44           1     0
# 45           0     2
# 46           1     0
# 47           0     2
# 48           0     2
# 50           1     0

# %%
pd.crosstab(fit["Fitness"],fit["Gender"])
# Out:
# Gender   Female  Male
# Fitness
# 1             1     1
# 2            16    10
# 3            45    52
# 4             8    16
# 5             6    25

# %%
pd.crosstab(fit["MaritalStatus"], fit["Gender"])
# Out:
# Gender         Female  Male
# MaritalStatus
# Partnered          46    61
# Single             30    43

# %%
pd.crosstab(fit["Product"], fit['Gender'])
# Out:
# Gender   Female  Male
# Product
# TM195        40    40
# TM498        29    31
# TM798         7    33

# %%
pd.crosstab(fit["Product"], fit['MaritalStatus'])
# Out:
# MaritalStatus  Partnered  Single
# Product
# TM195                 48      32
# TM498                 36      24
# TM798                 23      17

# %%
pd.crosstab(fit["Gender"], fit['MaritalStatus'])
# Out:
# MaritalStatus  Partnered  Single
# Gender
# Female                46      30
# Male                  61      43

# %%
sns.countplot(x='Product', hue='Gender', data=fit)
# Out:
# <AxesSubplot:xlabel='Product', ylabel='count'>

# %%
sns.countplot(x='Product', hue='Fitness', data=fit)
# Out:
# <AxesSubplot:xlabel='Product', ylabel='count'>

# %%
### question 
### what is the number
## like is it the average age of females using TM195 who are partnered??
### it is mean of all the data 

pd.pivot_table(fit, index=['Product', 'Gender'], columns =['MaritalStatus'])
# Out:
#                       Age             Education              Fitness  \
# MaritalStatus   Partnered     Single  Partnered     Single Partnered
# Product Gender
# TM195   Female  28.333333  28.692308  14.888889  15.538462  2.851852
#         Male    31.380952  25.631579  15.428571  14.473684  2.857143
# TM498   Female  30.000000  28.142857  15.200000  15.214286  2.933333
#         Male    30.380952  25.200000  15.285714  14.500000  2.904762
# TM798   Female  29.000000  24.333333  17.500000  18.333333  5.000000
#         Male    30.000000  28.928571  17.421053  16.928571  4.631579
#
#                                 Income                     Miles              \
# MaritalStatus     Single     Partnered        Single   Partnered      Single
# Product Gender
# TM195   Female  2.923077  46153.777778  45742.384615   74.925926   78.846154
#         Male    3.263158  50028.000000  43265.842105   80.190476   99.526316
# ...

# %%
## what difference does aggfunc=len makes??
## agg func is the count of the data

pd.pivot_table(fit, index=['Product', 'Gender'], columns =['MaritalStatus'], aggfunc=len)
# Out:
#                      Age        Education          Fitness           Income  \
# MaritalStatus  Partnered Single Partnered Single Partnered Single Partnered
# Product Gender
# TM195   Female        27     13        27     13        27     13        27
#         Male          21     19        21     19        21     19        21
# TM498   Female        15     14        15     14        15     14        15
#         Male          21     10        21     10        21     10        21
# TM798   Female         4      3         4      3         4      3         4
#         Male          19     14        19     14        19     14        19
#
#                           Miles            Usage
# MaritalStatus  Single Partnered Single Partnered Single
# Product Gender
# TM195   Female     13        27     13        27     13
#         Male       19        21     19        21     19
# TM498   Female     14        15     14        15     14
# ...

# %%
### Income specific pivot table
### the numbers are mean of the income

pd.pivot_table(fit, 'Income', index=['Product','Gender'], columns=['MaritalStatus'] )
# Out:
# MaritalStatus      Partnered        Single
# Product Gender
# TM195   Female  46153.777778  45742.384615
#         Male    50028.000000  43265.842105
# TM498   Female  49724.800000  48920.357143
#         Male    49378.285714  47071.800000
# TM798   Female  84972.250000  58516.000000
#         Male    81431.368421  68216.428571

# %%
pd.pivot_table(fit, 'Income', index=['Product','Gender'], columns=['MaritalStatus'] , aggfunc=len )
# Out:
# MaritalStatus   Partnered  Single
# Product Gender
# TM195   Female         27      13
#         Male           21      19
# TM498   Female         15      14
#         Male           21      10
# TM798   Female          4       3
#         Male           19      14

# %%
pd.pivot_table(fit, 'Miles' , index=['Product', 'Gender'], columns= ['MaritalStatus'])
# Out:
# MaritalStatus    Partnered      Single
# Product Gender
# TM195   Female   74.925926   78.846154
#         Male     80.190476   99.526316
# TM498   Female   94.000000   80.214286
#         Male     87.238095   91.100000
# TM798   Female  215.000000  133.333333
#         Male    176.315789  147.571429

# %%
sns.pairplot(fit,diag_kind='kde')

# %%
fit['Age'].std()
# Out:
# 6.943498135399795

# %%
fit['Age'].mean()
# Out:
# 28.788888888888888

# %%
fit.hist(by='Gender', column= 'Age')
# Out:
# array([<AxesSubplot:title={'center':'Female'}>,
#        <AxesSubplot:title={'center':'Male'}>], dtype=object)

# %%
fit.hist(by='Gender', column= 'Income')
# Out:
# array([<AxesSubplot:title={'center':'Female'}>,
#        <AxesSubplot:title={'center':'Male'}>], dtype=object)

# %%
fit.hist(by='Gender', column= 'Miles')
# Out:
# array([<AxesSubplot:title={'center':'Female'}>,
#        <AxesSubplot:title={'center':'Male'}>], dtype=object)

# %%
###

fit.hist(by='Product', column= 'Miles')
# Out:
# array([[<AxesSubplot:title={'center':'TM195'}>,
#         <AxesSubplot:title={'center':'TM498'}>],
#        [<AxesSubplot:title={'center':'TM798'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
### correlation matrix

corr=fit.corr()

# %%
corr
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
### without annotation
## correlation

sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
##With annotation

sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
fit.iloc
